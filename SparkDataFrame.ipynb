# %%
from pyspark.sql.types import DoubleType, StringType
from pyspark.sql import functions as f
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("SimpleApp").getOrCreate()

# %%
pathEmpresas = "empresas"
pathEstabelecimentos = "estabelecimentos"
pathSocios = "socios"

# %%
empresas = spark.read.csv(pathEmpresas, sep=';', inferSchema=True)
estabelecimentos = spark.read.csv(pathEstabelecimentos, sep=';', inferSchema=True)
socios = spark.read.csv(pathSocios, sep=';', inferSchema=True)

# %%
empresas.count()
# Out:
# 4585679

# %%
estabelecimentos.count()
# Out:
# 4836219

# %%
socios.count()
# Out:
# 2046430

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#      _c0  _c1  _c2  _c3                         _c4  _c5       _c6  _c7   _c8  \
# 0   4519    1   48    1                    GIRAFFAS    8  19950331    1  None
# 1   8638    1   79    1       AGROPECUARIA FAGUNDES    8  20150209   73  None
# 2  11748    1   90    1                        None    4  20181219   63  None
# 3  12027    1    2    1                        None    8  20081231   71  None
# 4  13289    1   83    1  JS MATERIAIS DE CONSTRUCAO    2  20040123    0  None
#
#    _c9  ...  _c20  _c21      _c22  _c23  _c24 _c25  _c26  \
# 0  NaN  ...  6219  None      None  None  None  NaN  None
# 1  NaN  ...  7255  None      None  None  None  NaN  None
# 2  NaN  ...  7097  None      None  None  None  NaN  None
# 3  NaN  ...  7107  None      None  None  None  NaN  None
# 4  NaN  ...  6915    19  35811286  None  None  NaN  None
#
#                            _c27  _c28 _c29
# 0                          None  None  NaN
# 1                          None  None  NaN
# 2                          None  None  NaN
# 3                          None  None  NaN
# 4  CONTATO@LEONECONTABIL.COM.BR  None  NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Manipulação de Dataframes
# ### Renomeando as colunas

# %%
empresasColNames = ['cnpj_basico', 'razao_social_nome_empresarial', 'natureza_juridica', 'qualificacao_do_responsavel', 'capital_social_da_empresa', 'porte_da_empresa', 'ente_federativo_responsavel']

estabsColNames = ['cnpj_basico', 'cnpj_ordem', 'cnpj_dv', 'identificador_matriz_filial', 'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral', 'motivo_situacao_cadastral', 'nome_da_cidade_no_exterior', 'pais', 'data_de_inicio_atividade', 'cnae_fiscal_principal', 'cnae_fiscal_secundaria', 'tipo_de_logradouro', 'logradouro', 'numero', 'complemento', 'bairro', 'cep', 'uf', 'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2', 'ddd_do_fax', 'fax', 'correio_eletronico', 'situacao_especial', 'data_da_situacao_especial']

sociosColNames = ['cnpj_basico', 'identificador_de_socio', 'nome_do_socio_ou_razao_social', 'cnpj_ou_cpf_do_socio', 'qualificacao_do_socio', 'data_de_entrada_sociedade', 'pais', 'representante_legal', 'nome_do_representante', 'qualificacao_do_representante_legal', 'faixa_etaria']

# %%
# Código do curso

# for index, colName in enumerate(empresasColNames):
#     empresas = empresas.withColumnRenamed(f"_c{index}", colName)

# for index, colName in enumerate(estabsColNames):
#     estabelecimentos = estabelecimentos.withColumnRenamed(f"_c{index}", colName)

# for index, colName in enumerate(sociosColNames):
#     socios = socios.withColumnRenamed(f"_c{index}", colName)

# Melhor forma
empresas = empresas.toDF(*empresasColNames)
estabelecimentos = estabelecimentos.toDF(*estabsColNames)
socios = socios.toDF(*sociosColNames)

# %%
empresas.columns
# Out:
# ['cnpj_basico',
#  'razao_social_nome_empresarial',
#  'natureza_juridica',
#  'qualificacao_do_responsavel',
#  'capital_social_da_empresa',
#  'porte_da_empresa',
#  'ente_federativo_responsavel']

# %%
empresas.limit(5).toPandas()
# Out:
#    cnpj_basico                      razao_social_nome_empresarial  \
# 0         4519                              DANIELA DA SILVA CRUZ
# 1         8638                           JOAO DOS SANTOS FAGUNDES
# 2        11748  PANIFICADORA E CONFEITARIA CONFIANCA RIO PRETO...
# 3        12027                                L G SORVETERIA LTDA
# 4        13289                     ANDREIA CRISTINA DELSIN EIRELI
#
#    natureza_juridica  qualificacao_do_responsavel capital_social_da_empresa  \
# 0               2135                           50                      0,00
# 1               2135                           50                      0,00
# 2               2062                           49                      0,00
# 3               2062                           49                      0,00
# 4               2305                           65                 100000,00
#
#    porte_da_empresa ente_federativo_responsavel
# 0                 5                        None
# 1                 5                        None
# 2                 1                        None
# 3                 5                        None
# 4                 1                        None

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         4519           1       48                            1
# 1         8638           1       79                            1
# 2        11748           1       90                            1
# 3        12027           1        2                            1
# 4        13289           1       83                            1
#
#                 nome_fantasia  situacao_cadastral  data_situacao_cadastral  \
# 0                    GIRAFFAS                   8                 19950331
# 1       AGROPECUARIA FAGUNDES                   8                 20150209
# 2                        None                   4                 20181219
# 3                        None                   8                 20081231
# 4  JS MATERIAIS DE CONSTRUCAO                   2                 20040123
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ...  municipio  \
# 0                          1                       None   NaN  ...       6219
# 1                         73                       None   NaN  ...       7255
# 2                         63                       None   NaN  ...       7097
# 3                         71                       None   NaN  ...       7107
# 4                          0                       None   NaN  ...       6915
#
#    ddd_1 telefone_1 ddd_2 telefone_2 ddd_do_fax   fax  \
# 0   None       None  None       None        NaN  None
# 1   None       None  None       None        NaN  None
# 2   None       None  None       None        NaN  None
# 3   None       None  None       None        NaN  None
# 4     19   35811286  None       None        NaN  None
#
#              correio_eletronico  situacao_especial data_da_situacao_especial
# 0                          None               None                       NaN
# 1                          None               None                       NaN
# 2                          None               None                       NaN
# 3                          None               None                       NaN
# 4  CONTATO@LEONECONTABIL.COM.BR               None                       NaN
#
# [5 rows x 30 columns]

# %%
socios.limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio  data_de_entrada_sociedade  \
# 0          ***678188**                     22                   19940725
# 1          ***637848**                     28                   19940725
# 2          ***786068**                     49                   19940516
# 3          ***442348**                     49                   19940516
# 4          ***760388**                     49                   19940609
#
#    pais representante_legal nome_do_representante  \
# 0   NaN         ***000000**                  None
# 1   NaN         ***000000**                  None
# 2   NaN         ***000000**                  None
# 3   NaN         ***000000**                  None
# 4   NaN         ***000000**                  None
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: string (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: integer (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: integer (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: integer (nullable = true)

# %%
socios.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- identificador_de_socio: integer (nullable = true)
#  |-- nome_do_socio_ou_razao_social: string (nullable = true)
#  |-- cnpj_ou_cpf_do_socio: string (nullable = true)
#  |-- qualificacao_do_socio: integer (nullable = true)
#  |-- data_de_entrada_sociedade: integer (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- representante_legal: string (nullable = true)
#  |-- nome_do_representante: string (nullable = true)
#  |-- qualificacao_do_representante_legal: integer (nullable = true)
#  |-- faixa_etaria: integer (nullable = true)

# %%
empresas = empresas.withColumn('capital_social_da_empresa', f.regexp_replace('capital_social_da_empresa', ',', '.'))

# %%
empresas = empresas.withColumn('capital_social_da_empresa', empresas['capital_social_da_empresa'].cast(DoubleType()))

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
estabelecimentos = estabelecimentos.withColumn(
        "data_situacao_cadastral",
        f.to_date(estabelecimentos.data_situacao_cadastral.cast(StringType()), 'yyyyMMdd')
    ).withColumn(
        "data_de_inicio_atividade",
        f.to_date(estabelecimentos.data_de_inicio_atividade.cast(StringType()), 'yyyyMMdd')
    ).withColumn(
        "data_da_situacao_especial",
        f.to_date(estabelecimentos.data_da_situacao_especial.cast(StringType()), 'yyyyMMdd')
    )

# %%
estabelecimentos.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: date (nullable = true)

# %%
estabelecimentos.limit(5).toPandas()
# Out:
#    cnpj_basico  cnpj_ordem  cnpj_dv  identificador_matriz_filial  \
# 0         4519           1       48                            1
# 1         8638           1       79                            1
# 2        11748           1       90                            1
# 3        12027           1        2                            1
# 4        13289           1       83                            1
#
#                 nome_fantasia  situacao_cadastral data_situacao_cadastral  \
# 0                    GIRAFFAS                   8              1995-03-31
# 1       AGROPECUARIA FAGUNDES                   8              2015-02-09
# 2                        None                   4              2018-12-19
# 3                        None                   8              2008-12-31
# 4  JS MATERIAIS DE CONSTRUCAO                   2              2004-01-23
#
#    motivo_situacao_cadastral nome_da_cidade_no_exterior  pais  ... municipio  \
# 0                          1                       None   NaN  ...      6219
# 1                         73                       None   NaN  ...      7255
# 2                         63                       None   NaN  ...      7097
# 3                         71                       None   NaN  ...      7107
# 4                          0                       None   NaN  ...      6915
#
#    ddd_1 telefone_1 ddd_2 telefone_2 ddd_do_fax   fax  \
# 0   None       None  None       None        NaN  None
# 1   None       None  None       None        NaN  None
# 2   None       None  None       None        NaN  None
# 3   None       None  None       None        NaN  None
# 4     19   35811286  None       None        NaN  None
#
#              correio_eletronico  situacao_especial data_da_situacao_especial
# 0                          None               None                      None
# 1                          None               None                      None
# 2                          None               None                      None
# 3                          None               None                      None
# 4  CONTATO@LEONECONTABIL.COM.BR               None                      None
#
# [5 rows x 30 columns]

# %%
socios = socios.withColumn(
        "data_de_entrada_sociedade",
        f.to_date(socios.data_de_entrada_sociedade.cast(StringType()), 'yyyyMMdd')
    )

# %% [markdown]
# ## Seleções e consultas

# %%
empresas.select('*').show(5, False)
# Out:
# +-----------+---------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial                      |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+---------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |4519       |DANIELA DA SILVA CRUZ                              |2135             |50                         |0.0                      |5               |NULL                       |
# |8638       |JOAO DOS SANTOS FAGUNDES                           |2135             |50                         |0.0                      |5               |NULL                       |
# |11748      |PANIFICADORA E CONFEITARIA CONFIANCA RIO PRETO LTDA|2062             |49                         |0.0                      |1               |NULL                       |
# |12027      |L G SORVETERIA LTDA                                |2062             |49                         |0.0                      |5               |NULL                       |
# |13289      |ANDREIA CRISTINA DELSIN EIRELI                     |2305             |65                         |100000.0                 |1               |NULL                       |
# +-----------+---------------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# only showing top 5 rows

# %%
empresas.select('natureza_juridica', 'porte_da_empresa', 'capital_social_da_empresa').show(5, False)
# Out:
# +-----------------+----------------+-------------------------+
# |natureza_juridica|porte_da_empresa|capital_social_da_empresa|
# +-----------------+----------------+-------------------------+
# |2135             |5               |0.0                      |
# |2135             |5               |0.0                      |
# |2062             |1               |0.0                      |
# |2062             |5               |0.0                      |
# |2305             |1               |100000.0                 |
# +-----------------+----------------+-------------------------+
# only showing top 5 rows

# %%
socios.select(
    'nome_do_socio_ou_razao_social', 'faixa_etaria', f.year('data_de_entrada_sociedade').alias('data_entrada')
).show(5, False)
# Out:
# +-------------------------------+------------+------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|data_entrada|
# +-------------------------------+------------+------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994        |
# |CRISTINA HUNDERTMARK           |7           |1994        |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994        |
# |EDUARDO BERRINGER STEPHAN      |5           |1994        |
# |HANNE MAHFOUD FADEL            |8           |1994        |
# +-------------------------------+------------+------------+
# only showing top 5 rows

# %%
estabelecimentos.select(
    'nome_fantasia', 'municipio',
    f.year('data_de_inicio_atividade').alias('ano_de_inicio_atividade'),
    f.month('data_de_inicio_atividade').alias('mes_de_inicio_atividade'),
).show(5, False)
# Out:
# +--------------------------+---------+-----------------------+-----------------------+
# |nome_fantasia             |municipio|ano_de_inicio_atividade|mes_de_inicio_atividade|
# +--------------------------+---------+-----------------------+-----------------------+
# |GIRAFFAS                  |6219     |1994                   |5                      |
# |AGROPECUARIA FAGUNDES     |7255     |1994                   |5                      |
# |NULL                      |7097     |1994                   |5                      |
# |NULL                      |7107     |1994                   |6                      |
# |JS MATERIAIS DE CONSTRUCAO|6915     |1994                   |6                      |
# +--------------------------+---------+-----------------------+-----------------------+
# only showing top 5 rows

# %% [markdown]
# ## Identificando valores nulos

# %%
estabelecimentos.limit(2).show()
# Out:
# +-----------+----------+-------+---------------------------+--------------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+-----------------+------+-------------------+----------------+--------+---+---------+-----+----------+-----+----------+----------+----+------------------+-----------------+-------------------------+
# |cnpj_basico|cnpj_ordem|cnpj_dv|identificador_matriz_filial|       nome_fantasia|situacao_cadastral|data_situacao_cadastral|motivo_situacao_cadastral|nome_da_cidade_no_exterior|pais|data_de_inicio_atividade|cnae_fiscal_principal|cnae_fiscal_secundaria|tipo_de_logradouro|       logradouro|numero|        complemento|          bairro|     cep| uf|municipio|ddd_1|telefone_1|ddd_2|telefone_2|ddd_do_fax| fax|correio_eletronico|situacao_especial|data_da_situacao_especial|
# +-----------+----------+-------+---------------------------+--------------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+-----------------+------+-------------------+----------------+--------+---+---------+-----+----------+-----+----------+----------+----+------------------+-----------------+-------------------------+
# |       4519|         1|     48|                          1|            GIRAFFAS|                 8|             1995-03-31|                        1|                      NULL|NULL|              1994-05-16|              5611203|                  NULL|               RUA|    HENRIQUE SAVI| 15 55|LOJA UN2A 01 TERREO|JARDIM AEROPORTO|17012205| SP|     6219| NULL|      NULL| NULL|      NULL|      NULL|NULL|              NULL|             NULL|                     NULL|
# |       8638|         1|     79|                          1|AGROPECUARIA FAGU...|                 8|             2015-02-09|                       73|                      NULL|NULL|              1994-05-24|              4771704|                  NULL|           AVENIDA|EUCLIDES DA CUNHA|   474|              SALAO|          CENTRO|19275000| SP|     7255| NULL|      NULL| NULL|      NULL|      NULL|NULL|              NULL|             NULL|                     NULL|
# +-----------+----------+-------+---------------------------+--------------------+------------------+-----------------------+-------------------------+--------------------------+----+------------------------+---------------------+----------------------+------------------+-----------------+------+-------------------+----------------+--------+---+---------+-----+----------+-----+----------+----------+----+------------------+-----------------+-------------------------+

# %%
socios.select([f.count(f.when(f.isnull(c), 1)).alias(c) for c in socios.columns]).show()
# Out:
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social|cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|   pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+
# |          0|                     0|                          208|                1234|                    0|                        1|2038255|                  0|              1995432|                                  0|           0|
# +-----------+----------------------+-----------------------------+--------------------+---------------------+-------------------------+-------+-------------------+---------------------+-----------------------------------+------------+

# %%
socios.na.fill(0).limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25     0
# 1          ***637848**                     28                1994-07-25     0
# 2          ***786068**                     49                1994-05-16     0
# 3          ***442348**                     49                1994-05-16     0
# 4          ***760388**                     49                1994-06-09     0
#
#   representante_legal nome_do_representante  \
# 0         ***000000**                  None
# 1         ***000000**                  None
# 2         ***000000**                  None
# 3         ***000000**                  None
# 4         ***000000**                  None
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %%
socios.na.fill('-').limit(5).toPandas()
# Out:
#    cnpj_basico  identificador_de_socio    nome_do_socio_ou_razao_social  \
# 0          411                       2      LILIANA PATRICIA GUASTAVINO
# 1          411                       2             CRISTINA HUNDERTMARK
# 2         5813                       2  CELSO EDUARDO DE CASTRO STEPHAN
# 3         5813                       2        EDUARDO BERRINGER STEPHAN
# 4        14798                       2              HANNE MAHFOUD FADEL
#
#   cnpj_ou_cpf_do_socio  qualificacao_do_socio data_de_entrada_sociedade  pais  \
# 0          ***678188**                     22                1994-07-25   NaN
# 1          ***637848**                     28                1994-07-25   NaN
# 2          ***786068**                     49                1994-05-16   NaN
# 3          ***442348**                     49                1994-05-16   NaN
# 4          ***760388**                     49                1994-06-09   NaN
#
#   representante_legal nome_do_representante  \
# 0         ***000000**                     -
# 1         ***000000**                     -
# 2         ***000000**                     -
# 3         ***000000**                     -
# 4         ***000000**                     -
#
#    qualificacao_do_representante_legal  faixa_etaria
# 0                                    0             7
# 1                                    0             7
# 2                                    0             8
# 3                                    0             5
# 4                                    0             8

# %% [markdown]
# ## Ordenando os valores

# %%
socios.select(
    "nome_do_socio_ou_razao_social", "faixa_etaria", f.year('data_de_entrada_sociedade').alias('ano_de_entrada')
).show(5, False)
# Out:
# +-------------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social  |faixa_etaria|ano_de_entrada|
# +-------------------------------+------------+--------------+
# |LILIANA PATRICIA GUASTAVINO    |7           |1994          |
# |CRISTINA HUNDERTMARK           |7           |1994          |
# |CELSO EDUARDO DE CASTRO STEPHAN|8           |1994          |
# |EDUARDO BERRINGER STEPHAN      |5           |1994          |
# |HANNE MAHFOUD FADEL            |8           |1994          |
# +-------------------------------+------------+--------------+
# only showing top 5 rows

# %%
socios.select(
    "nome_do_socio_ou_razao_social", "faixa_etaria", f.year('data_de_entrada_sociedade').alias('ano_de_entrada')
).orderBy(['faixa_etaria', 'ano_de_entrada'], ascending=[False, False]).show(15, False)
# Out:
# +-----------------------------+------------+--------------+
# |nome_do_socio_ou_razao_social|faixa_etaria|ano_de_entrada|
# +-----------------------------+------------+--------------+
# |ANDRE PAUL GABAY             |9           |2021          |
# |APPARECIDA ALBANI DE LIMA    |9           |2021          |
# |YASUKO KIYOMOTO HORIE        |9           |2021          |
# |UMBERTO BASTOS SACCHELLI     |9           |2021          |
# |OTAVIO BENTO DO NACIMENTO    |9           |2021          |
# |MARIA CELIAO SACCHELLI       |9           |2021          |
# |JANYR BELLUCI MIDUATI        |9           |2021          |
# |NORBERTO AGOSTINHO           |9           |2021          |
# |CARMINDA ALICE DE MORAIS     |9           |2021          |
# |HERCILIO COSTA               |9           |2021          |
# |ALTIVO DE SOUZA              |9           |2021          |
# |RUY BARRETO                  |9           |2021          |
# |MARIZE DA ROSA LIMA          |9           |2021          |
# |MARIA DO CEU DOS SANTOS      |9           |2021          |
# |MIGUEL CARLOS CALASANS SIMOES|9           |2021          |
# +-----------------------------+------------+--------------+
# only showing top 15 rows

# %%
empresas.where(
    "capital_social_da_empresa==50"
).show(5, False)
# Out:
# +-----------+--------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial               |natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+--------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |14715041   |LIDIANE MARIA DO NASCIMENTO 14542418707     |2135             |50                         |50.0                     |1               |NULL                       |
# |20601885   |CRISTIANO AKIHITO BORDIN 04370949955        |2135             |50                         |50.0                     |1               |NULL                       |
# |23661983   |VITOR ALOISIO DO NASCIMENTO GUIA 12663882739|2135             |50                         |50.0                     |1               |NULL                       |
# |23714726   |JOSELINA PANSINI CORREIA 05265948708        |2135             |50                         |50.0                     |1               |NULL                       |
# |26022246   |SUZANE SILVA DE OLIVEIRA 06850709992        |2135             |50                         |50.0                     |1               |NULL                       |
# +-----------+--------------------------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# only showing top 5 rows

# %%
socios.select(
    "nome_do_socio_ou_razao_social"
).filter(
    socios.nome_do_socio_ou_razao_social.startswith("ANTONIO")
).filter(
    socios.nome_do_socio_ou_razao_social.endswith("ALVES")
).limit(10).toPandas()
# Out:
#       nome_do_socio_ou_razao_social
# 0       ANTONIO ELICIO SANTOS ALVES
# 1            ANTONIO DE PADUA ALVES
# 2       ANTONIO EDUARDO ROCHA ALVES
# 3              ANTONIO ALCINO ALVES
# 4         ANTONIO MASCARENHAS ALVES
# 5  ANTONIO MARCELO ARAUJO GONCALVES
# 6      ANTONIO VILMAR PEREIRA ALVES
# 7       ANTONIO RODRIGUES GONCALVES
# 8                ANTONIO JOSE ALVES
# 9       ANTONIO APARECIDO GONCALVES

# %%
socios.where(socios.nome_do_socio_ou_razao_social.like('%ALVES%')).show(truncate=False)
# Out:
# +-----------+----------------------+-------------------------------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |cnpj_basico|identificador_de_socio|nome_do_socio_ou_razao_social                    |cnpj_ou_cpf_do_socio|qualificacao_do_socio|data_de_entrada_sociedade|pais|representante_legal|nome_do_representante|qualificacao_do_representante_legal|faixa_etaria|
# +-----------+----------------------+-------------------------------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# |427873     |2                     |ADRIANA GONCALVES ROBERTA FERREIRA               |***143386**         |22                   |2004-01-13               |NULL|***000000**        |NULL                 |0                                  |5           |
# |493021     |2                     |JOSE LUIZ FERREIRA ALVES                         |***241248**         |49                   |1995-03-16               |NULL|***000000**        |NULL                 |0                                  |6           |
# |860355     |2                     |NATANA ALVES DE ARAUJO                           |***149211**         |49                   |2015-03-23               |NULL|***000000**        |NULL                 |0                                  |3           |
# |985942     |2                     |MARILZA ALDINA SANT ANNA ALVES                   |***114507**         |49                   |1995-12-21               |NULL|***000000**        |NULL                 |0                                  |6           |
# |985942     |2                     |CARLOS HENRIQUE DE CASTRO ALVES                  |***094227**         |49                   |1995-12-21               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1103621    |2                     |CLEUZIMAR ALVES PEREIRA                          |***896211**         |16                   |2016-04-05               |NULL|***000000**        |NULL                 |0                                  |4           |
# |1220747    |2                     |NELTI GONCALVES DE SOUZA                         |***609349**         |49                   |1996-05-09               |NULL|***000000**        |NULL                 |0                                  |7           |
# |1220747    |2                     |ANTONI NELTI GONCALVES DE SOUZA                  |***708929**         |22                   |2004-06-01               |NULL|***000000**        |NULL                 |0                                  |4           |
# |1236482    |2                     |ELIANE APARECIDA ALVES DE OLIVEIRA               |***636409**         |49                   |1996-06-05               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1249238    |2                     |DANIELA LOUREIRO ALVES                           |***295536**         |22                   |2016-06-03               |NULL|***000000**        |NULL                 |0                                  |4           |
# |1292695    |2                     |ANTONIO ALVES DO NASCIMENTO                      |***894661**         |16                   |2005-09-12               |NULL|***000000**        |NULL                 |0                                  |7           |
# |1317054    |2                     |CUSTODIO ODILON ALVES DA FONSECA                 |***468706**         |49                   |1999-05-14               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1322451    |2                     |MIRELLE MOLETTA ALVES DE CARVALHO                |***691409**         |22                   |1996-07-17               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1577920    |2                     |HUMBERTO GONCALVES DE ALMEIDA                    |***716911**         |49                   |1998-09-16               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1698594    |2                     |LUIZ FERNANDO ALVES DE PINHO                     |***789207**         |49                   |1997-01-31               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1780439    |2                     |ANTONIO GONCALVES FILHO                          |***125692**         |49                   |1997-04-17               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1786544    |2                     |ANA ALZIRA FELIX ALVES                           |***342242**         |49                   |1997-04-11               |NULL|***000000**        |NULL                 |0                                  |6           |
# |1797312    |2                     |LUIZ ROBERTO ALVES DE SOUZA                      |***275987**         |22                   |1997-04-17               |NULL|***000000**        |NULL                 |0                                  |7           |
# |1847254    |2                     |PATRICIA ANTUNES ALVES DA COSTA ALMEIDA CERQUEIRA|***675217**         |16                   |2008-09-05               |NULL|***000000**        |NULL                 |0                                  |6           |
# |2012140    |2                     |VERANILDA ALVES PAULO                            |***685127**         |49                   |1997-07-03               |NULL|***000000**        |NULL                 |0                                  |5           |
# +-----------+----------------------+-------------------------------------------------+--------------------+---------------------+-------------------------+----+-------------------+---------------------+-----------------------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Agregações e junções

# %%
socios.select(
    f.year('data_de_entrada_sociedade').alias('ano_de_entrada')
).where(
    'ano_de_entrada >= 2010'
).groupBy(
    'ano_de_entrada'
).count().orderBy('ano_de_entrada', ascending=True).show()
# Out:
# +--------------+------+
# |ano_de_entrada| count|
# +--------------+------+
# |          2010| 79337|
# |          2011| 83906|
# |          2012| 80101|
# |          2013| 83919|
# |          2014| 80590|
# |          2015| 80906|
# |          2016| 81587|
# |          2017| 90221|
# |          2018| 99935|
# |          2019|118248|
# |          2020|125927|
# |          2021| 56316|
# +--------------+------+

# %%
empresas.select(
    'cnpj_basico', 'porte_da_empresa', 'capital_social_da_empresa'
).groupBy('porte_da_empresa').agg(
    f.avg('capital_social_da_empresa').alias('capital_social_medio'),
    f.count('cnpj_basico').alias('frequencia')
).orderBy('porte_da_empresa', ascending=True).show()
# Out:
# +----------------+--------------------+----------+
# |porte_da_empresa|capital_social_medio|frequencia|
# +----------------+--------------------+----------+
# |            NULL|    8.35421888053467|      5985|
# |               1|   339994.5331350705|   3129043|
# |               3|  2601001.7677092687|    115151|
# |               5|   708660.4208249793|   1335500|
# +----------------+--------------------+----------+

# %%
empresas.select(
    'capital_social_da_empresa'
).summary().show()
# Out:
# +-------+-------------------------+
# |summary|capital_social_da_empresa|
# +-------+-------------------------+
# |  count|                  4585679|
# |   mean|        503694.5478542674|
# | stddev|     2.1118691490537742E8|
# |    min|                      0.0|
# |    25%|                      0.0|
# |    50%|                   1000.0|
# |    75%|                   7000.0|
# |    max|         3.22014670262E11|
# +-------+-------------------------+

# %%
socios.select(
    'nome_do_socio_ou_razao_social'
).summary().show()
# Out:
# +-------+-----------------------------+
# |summary|nome_do_socio_ou_razao_social|
# +-------+-----------------------------+
# |  count|                      2046222|
# |   mean|                         NULL|
# | stddev|                         NULL|
# |    min|         '' PROTENDE '' SI...|
# |    25%|                         NULL|
# |    50%|                         NULL|
# |    75%|                         NULL|
# |    max|         iDtrust Tecnologi...|
# +-------+-----------------------------+

# %%
estabelecimentos.select(
    'nome_fantasia'
).summary().show()
# Out:
# +-------+-------------+
# |summary|nome_fantasia|
# +-------+-------------+
# |  count|      2821513|
# |   mean|     Infinity|
# | stddev|          NaN|
# |    min|    !000 GRAU|
# |    25%|         33.0|
# |    50%|       9981.0|
# |    75%| 9.75695942E8|
# |    max|        �VILA|
# +-------+-------------+

# %% [markdown]
# ## Joins

# %%
empresas_join = estabelecimentos.join(empresas, 'cnpj_basico', how='inner')

# %%
empresas_join.printSchema()
# Out:
# root
#  |-- cnpj_basico: integer (nullable = true)
#  |-- cnpj_ordem: integer (nullable = true)
#  |-- cnpj_dv: integer (nullable = true)
#  |-- identificador_matriz_filial: integer (nullable = true)
#  |-- nome_fantasia: string (nullable = true)
#  |-- situacao_cadastral: integer (nullable = true)
#  |-- data_situacao_cadastral: date (nullable = true)
#  |-- motivo_situacao_cadastral: integer (nullable = true)
#  |-- nome_da_cidade_no_exterior: string (nullable = true)
#  |-- pais: integer (nullable = true)
#  |-- data_de_inicio_atividade: date (nullable = true)
#  |-- cnae_fiscal_principal: integer (nullable = true)
#  |-- cnae_fiscal_secundaria: string (nullable = true)
#  |-- tipo_de_logradouro: string (nullable = true)
#  |-- logradouro: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- complemento: string (nullable = true)
#  |-- bairro: string (nullable = true)
#  |-- cep: integer (nullable = true)
#  |-- uf: string (nullable = true)
#  |-- municipio: integer (nullable = true)
#  |-- ddd_1: string (nullable = true)
#  |-- telefone_1: string (nullable = true)
#  |-- ddd_2: string (nullable = true)
#  |-- telefone_2: string (nullable = true)
#  |-- ddd_do_fax: integer (nullable = true)
#  |-- fax: string (nullable = true)
#  |-- correio_eletronico: string (nullable = true)
#  |-- situacao_especial: string (nullable = true)
#  |-- data_da_situacao_especial: date (nullable = true)
#  |-- razao_social_nome_empresarial: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_do_responsavel: integer (nullable = true)
#  |-- capital_social_da_empresa: double (nullable = true)
#  |-- porte_da_empresa: integer (nullable = true)
#  |-- ente_federativo_responsavel: string (nullable = true)

# %%
freq = empresas_join.select(
    'cnpj_basico',
    f.year('data_de_inicio_atividade').alias('data_de_inicio')
).where('data_de_inicio >= 2010').groupBy('data_de_inicio').agg(
    f.count('cnpj_basico').alias('frequencia')
).orderBy('data_de_inicio', ascending=True)

# %%
freq.toPandas()
# Out:
#     data_de_inicio  frequencia
# 0             2010      154159
# 1             2011      172677
# 2             2012      232480
# 3             2013      198424
# 4             2014      202276
# 5             2015      212523
# 6             2016      265417
# 7             2017      237292
# 8             2018      275435
# 9             2019      325922
# 10            2020      400654
# 11            2021      153275

# %%
freq.union(
    freq.select(
        f.lit('Total').alias('data_de_inicio'),
        f.sum(freq.frequencia).alias('frequencia')
    )
).show()
# Out:
# +--------------+----------+
# |data_de_inicio|frequencia|
# +--------------+----------+
# |          2010|    154159|
# |          2011|    172677|
# |          2012|    232480|
# |          2013|    198424|
# |          2014|    202276|
# |          2015|    212523|
# |          2016|    265417|
# |          2017|    237292|
# |          2018|    275435|
# |          2019|    325922|
# |          2020|    400654|
# |          2021|    153275|
# |         Total|   2830534|
# +--------------+----------+

# %%
empresas.createOrReplaceTempView("empresasView")

# %%
spark.sql("SELECT * FROM empresasView").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |       4519|         DANIELA DA SILVA ...|             2135|                         50|                      0.0|               5|                       NULL|
# |       8638|         JOAO DOS SANTOS F...|             2135|                         50|                      0.0|               5|                       NULL|
# |      11748|         PANIFICADORA E CO...|             2062|                         49|                      0.0|               1|                       NULL|
# |      12027|          L G SORVETERIA LTDA|             2062|                         49|                      0.0|               5|                       NULL|
# |      13289|         ANDREIA CRISTINA ...|             2305|                         65|                 100000.0|               1|                       NULL|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# only showing top 5 rows

# %%
spark.sql("""
SELECT *
FROM empresasView
WHERE qualificacao_do_responsavel = 0
""").show(5)
# Out:
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |cnpj_basico|razao_social_nome_empresarial|natureza_juridica|qualificacao_do_responsavel|capital_social_da_empresa|porte_da_empresa|ente_federativo_responsavel|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# |   17734526|         INSTITUTO EDUCACI...|             8885|                          0|                      0.0|               5|                       NULL|
# |   20914560|         SERVICO DE NOTAS ...|             3034|                          0|                      0.0|               5|                       NULL|
# |    1436343|         CARTORIO DO REGIS...|             3034|                          0|                      0.0|               5|                       NULL|
# |    5716949|         CARTORIO DE 1 OFI...|             3034|                          0|                      0.0|               5|                       NULL|
# |   75428839|         TRANS AMERICA SOC...|             2178|                          0|                      0.0|               5|                       NULL|
# +-----------+-----------------------------+-----------------+---------------------------+-------------------------+----------------+---------------------------+
# only showing top 5 rows

# %%
empresas.write.csv(
    path='output',
    mode='overwrite',
    sep=';',
    header=True
)

# %%
# spark.stop()
